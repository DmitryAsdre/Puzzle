# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
names = ['test_1', 'test_2', 'test_3', 'test_4']

# %%
for name in names:
    df = pd.read_csv(name + '.csv')
    print(name)
    plt.figure(figsize=(15, 8))
    mask = df['Ratio'] > 1.2
    plt.xlabel("Ratio")
    plt.ylabel("#ofOperations")
    plt.plot(df['Ratio'][mask], df['#ofOperations'][mask])
    plt.plot()
# Out:
# test_1
# test_2
# test_3
# test_4

# %%
mask = df['Ratio'] > 1.2
plt.figure(figsize=(15, 7))
plt.plot(df['Ratio'][mask], df['#ofOperations'][mask])
